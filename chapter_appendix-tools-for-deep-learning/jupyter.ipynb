# %% [markdown]
# ### Cognifyz - Data Science Internship

# %% [markdown]
# Level 01 - Task 01

# %% [markdown]
# Data Exploration and Preprocessing

# %%
import warnings
warnings.filterwarnings('ignore')
